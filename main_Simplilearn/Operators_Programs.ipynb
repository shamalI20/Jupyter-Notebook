# %% [markdown]
# # Sting functions

# %% [markdown]
# #### Concatenation

# %%
"Hello" + "World"
# Out:
# 'HelloWorld'

# %% [markdown]
# #### Repetition

# %%
"*-*" * 3
# Out:
# '*-**-**-*'

# %% [markdown]
# #### Indexing

# %%
"Python"[0]
# Out:
# 'P'

# %%
"Python"[-1]
# Out:
# 'n'

# %% [markdown]
# #### Slicing

# %%
"Python"[2:8]
# Out:
# 'thon'

# %%
len("Python") # Size of string len()
# Out:
# 6

# %% [markdown]
# #### Immutable String

# %% [markdown]
# ![Escape_Sequence.png](attachment:Escape_Sequence.png)

# %% [markdown]
# #### Escape sequence demo

# %%
print("Sham\al Indurkar")
# Out:
# Shaml Indurkar

# %%
print("isn\'t she said.'")
# Out:
# isn't she said.'

# %%
s="First line.\nSecond line."   # \n -next line
print(s)
# Out:
# First line.
# Second line.

# %%
print('c:\some\name')
# Out:
# c:\some
# ame

# %%
print(r'c:\some name') # raw string
# Out:
# c:\some name

# %%
a=("Shamal Indurkar")
print(a.lower())
# Out:
# shamal indurkar

# %%
print(a.upper())
# Out:
# SHAMAL INDURKAR

# %%
print(a.startswith("H"))
# Out:
# False

# %%
print(a.startswith("S"))
# Out:
# True

# %%
print(a.startswith("s"))
# Out:
# False

# %%
print(a.replace("S","Z"))
# Out:
# Zhamal Indurkar

# %%
print(a.split(" "))
# convert string into list
# Out:
# ['Shamal', 'Indurkar']

# %%
print(a + str(" Kundlik"))
# Out:
# Shamal Indurkar Kundlik

# %%
a,b=20,10
print(b**a)   # ** Exponent, power calculation on calculators
# Out:
# 100000000000000000000

# %%
print(9//2) # after decimal points are removed.
# Out:
# 4

# %%
print(-9.0/2.0)
# Out:
# -4.5

# %%
a,b,c=10,20,1
c=a+b
print (c)
# Out:
# 30

# %%
c+=a
print (c)
# Out:
# 21

# %%
a,b,c=10,20,1 
c-=a
print(c)
# Out:
# -9

# %%
a,b,c=10,20,1
c=c-a
print(c)
# Out:
# -9
